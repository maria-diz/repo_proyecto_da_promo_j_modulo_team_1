# %% [markdown]
# CUERPO PRINCIPAL DEL JUEGO:

# %%
# Elegimos 'import random' para elegir una palabra de la lista de forma aleatoria. 
import random 

# Lista de palabras en la que la máquina elige de manera aleatoria una de ellas:

palabras =["perro","fruta","murcielago","ornitorrinco"] # lista de palabras.
palabra_secreta = random.choice(palabras) # palabra secreta elegida por la máquina de manera aleatoria.
palabra_raya= '-' * len(palabra_secreta) # la palabra secreta elegida se imprimirá con guiones para que sea más visual.
intentos = 0 # crear una variable para contabilizar el número de intentos.

# Aquí empieza el juego. Mensaje de bienvenida e instrucciones:

print(" O    ___________________________________    O")
print("/|\\   ¡BIENVENID@  AL JUEGO DEL AHORCADO!   /|\\")
print("/ \\   ___________________________________   / \\")
print(" ")
print("¿COMO SE JUEGA?")
print("Tu como jugador/a debes adivinar la palabra letra por letra hasta formar dicha palabra en su totalidad.\n¡CUIDADO! Solo tendras un maximo de 6 INTENTOS para poder adivinarla, ya que cada vez que falles, se irá añadiendo una parte del cuerpo al ahorcado.\nSi el dibujo del ahorcado se completa antes de que hayas adividado la papabra secreta ---> PIERDES.\nSi adivinas la palabra secreta al completo antes de que se dibuje el ahorcado en su totalidad ---> GANAS.")
print("                                                   ")
print("¿List@? Empezamos en...... 3 ...... 2 ...... 1 ....... ¡A POR TODAS!")
print(" ")


while intentos < 6: # mientras el número de intentos sea menor que seis, la condición será verdadera y el bucle seguirá corriendo.
     
    print(f" La palabra secreta es:  {palabra_raya}  ")  
    adivina_letra = input("Elige una letra")
    
    if adivina_letra in palabra_secreta:
         
        letra_adivinada_palabra = "" # nueva variable para ir formando la palabra secretra con las letras elegidas
        
        for letra in palabra_secreta: # itera en cada letra de la palabra secreta.
             if letra == adivina_letra or letra in palabra_raya: # si la letra de la palabra coincide con la letra elegida por el jugador.
                 letra_adivinada_palabra += letra                # si es así, esa letra se añadirá a la variable letra_adivinada_palabra.
                 
             else:
                letra_adivinada_palabra += "-"                   #si no es así, se añadirá un guion.
            
        palabra_raya = letra_adivinada_palabra # se actualiza el valor de la palabra_raya con las letras adivinadas que se han ido añadiendo a la variable letra_adivinada_palabra.


        if palabra_raya == palabra_secreta:
            print(f"¡ENHORABUENA! Efectivamente, la palabra secreta es: {palabra_secreta}. ¡BIEN JUGADO!")
            break # porque la condicion "palabra_raya == palabra_secreta" se ha cumplido, por lo que el juego termina y detiene el bucle.
    
       
        
    else: #si la letra no está en la palabra secreta, se van imprimiendo las partes del cuerpo del ahorcado:
        
        intentos += 1 # cada vez que el jugador introduzca una letra errónea, se incrementará el número de intentos en la variable hasta que llegue a 6 (su máximo) y la condición "intentos > 6" se volverá falsa.

        if intentos == 1:
            print("O")
        elif intentos == 2:
            print("O")
            print("|")
        elif intentos == 3:
            print(" O")
            print("/|")
        elif intentos == 4:
            print(" O")
            print("/|\\")
        elif intentos == 5:
            print(" O")
            print("/|\\")
            print("/")
        elif intentos == 6:
            print(" O")
            print("/|\\")
            print("/ \\")
            print("_____________________________________________")
            print(f"¡PERDISTE! La palabra secreta es ----> {palabra_secreta}")
            
            break #para salir del programa/ bucle.
# Out:
#  O    ___________________________________    O
# /|\   ¡BIENVENID@  AL JUEGO DEL AHORCADO!   /|\
# / \   ___________________________________   / \
#
# ¿COMO SE JUEGA?
# Tu como jugador/a debes adivinar la palabra letra por letra hasta formar dicha palabra en su totalidad.
# ¡CUIDADO! Solo tendras un maximo de 6 INTENTOS para poder adivinarla, ya que cada vez que falles, se irá añadiendo una parte del cuerpo al ahorcado.
# Si el dibujo del ahorcado se completa antes de que hayas adividado la papabra secreta ---> PIERDES.
# Si adivinas la palabra secreta al completo antes de que se dibuje el ahorcado en su totalidad ---> GANAS.
#
# ¿List@? Empezamos en...... 3 ...... 2 ...... 1 ....... ¡A POR TODAS!
#
# O
#  La palabra secreta es:  ------------
# O
# |
#  La palabra secreta es:  ------------
#  O
# /|
#  La palabra secreta es:  ------------
#  O
# /|\
#  La palabra secreta es:  ------------
#  O
# /|\
# /
#  La palabra secreta es:  ------------
#  O
# /|\
# / \
# _____________________________________________
# ¡PERDISTE! La palabra secreta es ----> ornitorrinco

# %% [markdown]
# DESDE AQUI LOS MARKDOWN Y CODE SON EJEMPLOS E INTENTOS DE LA CONSTRUCCIÓN DEL JUEGO Y SIMILARES:

# %% [markdown]
# AHORCADO
#
# EJEMPLO:
#
# palabra_secreta = "pan"
# palabra_oculta = '*' * len(palabra_secreta)
#
# #si queremos ver la palabra printada en *** hacemos el print de la palabra oculta
# lista = []
#
# while len(lista) != len(palabra_secreta):
#     letra = input("Empieza el juego, dime una letra para saber si esta dentro de la palabra secreta")
#
#     if letra in palabra_secreta:
#         print(f"La letra {letra} esta en la palabra" )
#         posicion_letra = palabra_secreta.index(letra)
#         lista.append(letra)
#
# print(f"La palabra es {''.join(lista)} ")
#
#
# Ejercicio 4: Juego de Adivinar la Palabra
#
# Elige una palabra secreta y ocúltala utilizando asteriscos, por ejemplo, "secreto" se muestra como "*******".
#
# Permite al usuario adivinar letras una por una.
#
# Si la letra adivinada está en la palabra secreta, muestra la palabra con las letras descubiertas y los asteriscos.
#
# Si la letra no está en la palabra secreta, resta una vida al jugador.
#
# El juego continúa hasta que el jugador adivine la palabra
# llevó al final.

# %%
while:len(palabras) == 

if adivina_letra in random.choice(palabras):
    print(f"Genial, tu letra '{adivina_letra}' está dentro de la palabra secreta.")
else:
    print(f" Lo siento, tu letra '{adivina_letra}' no es correcta. Sigue intentándolo.")

# %%
import random

def obtener_palabra_aleatoria():
    palabras = ["python", "programacion", "juego", "desarrollador", "codigo", "ahorcado"]
    return random.choice(palabras)

def mostrar_palabra(palabra, letras_adivinadas):
    return " ".join([letra if letra in letras_adivinadas else "_" for letra in palabra])

def jugar_ahorcado():
    palabra = obtener_palabra_aleatoria()
    letras_adivinadas = set()
    intentos = 6
    errores = 0

    print("¡Bienvenido al juego del ahorcado!")
    print("Adivina la palabra, letra por letra.")

    while errores < intentos:
        print("\n" + mostrar_palabra(palabra, letras_adivinadas))
        letra = input("Introduce una letra: ").lower()

        if letra in letras_adivinadas:
            print("Ya has adivinado esa letra. Intenta con otra.")
            continue

        if letra in palabra:
            letras_adivinadas.add(letra)
            print("¡Bien hecho! Esa letra está en la palabra.")
            if all(letra in letras_adivinadas for letra in palabra):
                print(f"¡Felicidades! Has adivinado la palabra: {palabra}")
                break
        else:
            errores += 1
            print(f"Letra incorrecta. Te quedan {intentos - errores} intentos.")

    if errores == intentos:
        print(f"Has perdido. La palabra era: {palabra}")

jugar_ahorcado()

# %%
import random

def elegir_palabra():
    palabras = ["python", "programacion", "desarrollo", "codigo", "juego"]
    return random.choice(palabras)

def mostrar_palabra(palabra, letras_adivinadas):
    return "".join([letra if letra in letras_adivinadas else "_" for letra in palabra])
def jugar_ahorcado():
    palabra = elegir_palabra()
    letras_adivinadas = set()
    intentos_restantes = 6
    letras_erroneas = set()

    print("¡Bienvenido al juego del Ahorcado!")
    print(f"La palabra tiene {len(palabra)} letras.")

    while intentos_restantes > 0:
        print("\nPalabra: ", mostrar_palabra(palabra, letras_adivinadas))
        print(f"Letras erróneas: {' '.join(letras_erroneas)}")
        print(f"Intentos restantes: {intentos_restantes}")

        letra = input("Adivina una letra: ").lower()

        if letra in letras_adivinadas or letra in letras_erroneas:
            print("Ya has adivinado esa letra. Intenta con otra.")
            continue

        if letra in palabra:
            letras_adivinadas.add(letra)
            print(f"¡Bien hecho! La letra '{letra}' está en la palabra.")
        else:
            letras_erroneas.add(letra)
            intentos_restantes -= 1
            print(f"La letra '{letra}' no está en la palabra.")

        if all(letra in letras_adivinadas for letra in palabra):
            print("\n¡Felicidades! Has adivinado la palabra:", palabra)
            break
    else:
        print("\nTe has quedado sin intentos. La palabra era:", palabra)

if __name__ == "__main__":
    jugar_ahorcado()
# Out:
# ¡Bienvenido al juego del Ahorcado!
# La palabra tiene 6 letras.
#
# Palabra:  ______
# Letras erróneas:
# Intentos restantes: 6
# La letra 'p' no está en la palabra.
#
# Palabra:  ______
# Letras erróneas: p
# Intentos restantes: 5
# La letra 'l' no está en la palabra.
#
# Palabra:  ______
# Letras erróneas: l p
# Intentos restantes: 4
# ¡Bien hecho! La letra 'o' está en la palabra.
#
# Palabra:  _o___o
# Letras erróneas: l p
# Intentos restantes: 4
# La letra 'f' no está en la palabra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l p
# Intentos restantes: 3
# La letra 'fy' no está en la palabra.
#
# Palabra:  _o___o
# Letras erróneas: f l p fy
# Intentos restantes: 2
# La letra 'h' no está en la palabra.
#
# Palabra:  _o___o
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o___o
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# ¡Bien hecho! La letra 'g' está en la palabra.
#
# Palabra:  _o__go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _o__go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# ¡Bien hecho! La letra 'd' está en la palabra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# Ya has adivinado esa letra. Intenta con otra.
#
# Palabra:  _od_go
# Letras erróneas: f l h p fy
# Intentos restantes: 1
# La letra 's' no está en la palabra.
#
# Te has quedado sin intentos. La palabra era: codigo
